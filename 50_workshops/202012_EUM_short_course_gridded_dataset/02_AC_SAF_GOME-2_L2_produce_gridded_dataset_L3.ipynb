# %% [markdown]
# <img src='./img/EU-Copernicus-EUM_3Logos.png' alt='Logo EU Copernicus EUMETSAT' align='right' width='50%'></img>

# %% [markdown]
# <br>

# %% [markdown]
# <a href="./00_index.ipynb"><< Index </a><br>
# <a href="./01_introduction_to_python_and_jupyter.ipynb"><< 01 - Introduction to Python and Jupyter </a><span style="float:right;"><a href="./03_case_study_covid-19_GOME2_anomaly_map.ipynb">03 - Covid-19 case study - GOME-2 anomaly map >></a></span>

# %% [markdown]
# <br>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>METHODOLOGY</b></div>

# %% [markdown]
# # AC SAF GOME-2 - Produce monthly GOME-2 Level 3 (gridded) climate products

# %% [markdown]
# This modules provides an example how a monthly gridded (Level 3) climate record from GOME-2 Level 2 data can be produced.
# The full workflow is described in details on page 19 in the [Algorithm Theoretical Basis Document & Product User Manual for GOME-2 NO2 and H2O Level 3 Climate Products](https://acsaf.org/docs/atbd/Algorithm_Theoretical_Basis_Document_Product_User_Manual_NO2_H2O_TCDR_Nov_2017.pdf)
#
# The example produces a gridded data record for March 2020 for the atmospheric parameter `Nitrogen Dioxide (NO2)`.

# %% [markdown]
# #### This module has the following outline:
# - [Load Metop-A and Metop-B GOME-2 Level 2 data files for one month](#load)
# - [Mask and flag low-quality pixels](#mask)
# - [Binning of L2 data onto a defined two-dimensional grid](#binning)
# - [Visualize the gridded Level 3 NO2 climate record for March 2020](#visualize)

# %% [markdown]
# <br>

# %% [markdown]
# #### Load required libraries

# %%
# %matplotlib inline
import os
from netCDF4 import Dataset
import xarray as xr
import numpy as np
import ipynb
import glob

# Python libraries for visualisation
from matplotlib import pyplot as plt
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

from IPython.display import display, clear_output

import warnings
warnings.simplefilter(action = "ignore", category = AttributeError)

# %% [markdown]
# #### Load functions

# %%
from ipynb.fs.full.functions import load_l2_data_xr, generate_xr_from_1D_vec, visualize_pcolormesh, generate_masked_array

# %% [markdown]
# <hr>

# %% [markdown]
# ## <a id='load'></a>Load Metop-A and Metop-B GOME-2 Level 2 data files for one month

# %% [markdown]
# ### Load total column NO2, cloud fraction and index scan values for March 2020 from Metop-A

# %% [markdown]
# #### Load NO2 data values for one day in March 2020 into a xarray DataArray

# %% [markdown]
# The GOME-2 Level 2 data have been downloaded from DLR's ftp server. On the server, the data is organised by satellite (Metop-A and Metop-B) followed by a year, month and day folder structure.
#
# The data files for March 2020 are under `./eodata/gome2/offline/2a/2020/03/` and `./eodata/gome2/offline/2b/2020/03/`. Both folders contain subfolders for each day. The aim is to load all NO2 data values of one month into one xarray `DataArray` object.
#
# To do this, we create first a list of all the folders within the folder for March 2020 and call it `folder_list`. Next, we load the NO2 data files for one day in March 2020 into a xarray `DataArray` object. We use the [load_l2_data_xr](./functions.ipynb#load_l2_data_xr) function to do this.
#
# The loaded DataArray object with tropospheric NO2 values contains 211163 ground pixel values>

# %%
directory_2a= './eodata/gome2/offline/2a/2020/03/'

# %%
folder_list = glob.glob(directory_2a+'*')
data_array_a = load_l2_data_xr(folder_list[0],  
                               'TOTAL_COLUMNS', 
                               'NO2Tropo', 
                               'GEOLOCATION/LatitudeCentre', 
                               'GEOLOCATION/LongitudeCentre', 
                               1, 
                               paramname='NO2Tropo', 
                               unit='mol/cm\u00b2',
                               longname='Tropospheric column density of NO2')

data_array_a
# Out:
# <xarray.DataArray 'NO2Tropo' (ground_pixel: 211163)>
# array([-1., -1., -1., ..., -1., -1., -1.], dtype=float32)
# Coordinates:
#     latitude   (ground_pixel) float32 78.54998 78.497986 ... -84.389786
#     longitude  (ground_pixel) float32 198.78352 196.99515 ... 41.96278 38.35278
# Dimensions without coordinates: ground_pixel
# Attributes:
#     long_name:  Tropospheric column density of NO2
#     units:      mol/cm²

# %% [markdown]
# <br>

# %% [markdown]
# #### Load quality flag information (cloud fraction and index scan) as xarray DataArray objects

# %% [markdown]
# The [Product User Manual for GOME-2 NO2 and H2O Level 3 Climate Products](https://acsaf.org/docs/atbd/Algorithm_Theoretical_Basis_Document_Product_User_Manual_NO2_H2O_TCDR_Nov_2017.pdf) explains in detail the procedure how Level 3 climate products for NO2 and H2O are produced. Low quality measurements are flagged out in three ways:
# - negative values
# - pixels with a cloud fraction higher than 20%, and
# - backward scan pixels
#
# Cloud property and index scan information are part of each data file. Thus, additionally to the data values, we load the `cloud_fraction` as well as the `index_scan` information for one day in March 2020. Cloud fraction information are under the group path `ClOUD_PROPERTIES/CloudFraction` in the data file and index scan information are under `GEOLOCATION/IndexInScan`.
#
# Both information can be loaded by using the [load_l2_data_xr](./functions.ipynb#load_l2) function.

# %%
cloud_fraction_a = load_l2_data_xr(folder_list[0], 
                                   'CLOUD_PROPERTIES', 
                                   'CloudFraction', 
                                   'GEOLOCATION/LatitudeCentre', 
                                   'GEOLOCATION/LongitudeCentre', 
                                   1, 
                                   paramname='cloud_fraction', 
                                   unit='-', 
                                   longname='Cloud Fraction')

index_scan_a = load_l2_data_xr(folder_list[0], 
                               'GEOLOCATION', 
                               'IndexInScan', 
                               'GEOLOCATION/LatitudeCentre', 
                               'GEOLOCATION/LongitudeCentre', 
                               1, 
                               paramname='indexflag', 
                               unit='-', 
                               longname='Index in Scan')

# %% [markdown]
# <br>

# %% [markdown]
# #### Loop through all days of March 2020 and load NO2, cloud fraction and index scan values from Metop-A into one DataArray object

# %% [markdown]
# Once we built three data arrays, NO2 data values, cloud fraction information and index scan information, for one day, we can loop through the remaining days of the month and concatenate the additional information to each data array. For concatenating two data arrays, we can use xarray's function `concat`.
#
# We loop through the defined `folder_list` and skip the first entry. For each of the three data arrays, we first load all data files of the respective day into a xarray `DataArray` object (with the help of the [load_l2_data_xr](./functions.ipynb#load_l2) function and concatenate it to the existing `DataArray` objects, `data_array_a`, `cloud_fraction_a` and `index_scan_a` respectively.

# %%
for folder in folder_list[1:]:
    print(folder)
    data_array = load_l2_data_xr(folder, 
                                 'TOTAL_COLUMNS', 
                                 'NO2Tropo', 
                                 'GEOLOCATION/LatitudeCentre', 
                                 'GEOLOCATION/LongitudeCentre', 
                                 1, 
                                 paramname='NO2Tropo', 
                                 unit='mol/cm\u00b2',
                                 longname='Tropospheric column density of NO2')
    
    data_array_a = xr.concat([data_array_a, data_array], dim='ground_pixel')

    cloud_fraction = load_l2_data_xr(folder,
                                     'CLOUD_PROPERTIES', 
                                     'CloudFraction', 
                                     'GEOLOCATION/LatitudeCentre', 
                                     'GEOLOCATION/LongitudeCentre', 
                                     1, 
                                     paramname='cloud_fraction', 
                                     unit='-', 
                                     longname='Cloud Fraction')
    
    cloud_fraction_a = xr.concat([cloud_fraction_a, cloud_fraction], dim='ground_pixel')

    index_scan = load_l2_data_xr(folder,
                                 'GEOLOCATION', 
                                 'IndexInScan', 
                                 'GEOLOCATION/LatitudeCentre', 
                                 'GEOLOCATION/LongitudeCentre', 
                                 1, 
                                 paramname='indexflag', 
                                 unit='-', 
                                 longname='Index in Scan')
   
    index_scan_a = xr.concat([index_scan_a, index_scan], dim='ground_pixel')
# Out:
# ./eodata/gome2/offline/2a/2020/03/02
# ./eodata/gome2/offline/2a/2020/03/03
# ./eodata/gome2/offline/2a/2020/03/04
# ./eodata/gome2/offline/2a/2020/03/05
# ./eodata/gome2/offline/2a/2020/03/06
# ./eodata/gome2/offline/2a/2020/03/07
# ./eodata/gome2/offline/2a/2020/03/08
# ./eodata/gome2/offline/2a/2020/03/09
# ./eodata/gome2/offline/2a/2020/03/10
# ./eodata/gome2/offline/2a/2020/03/11
# ./eodata/gome2/offline/2a/2020/03/12
# ./eodata/gome2/offline/2a/2020/03/13
# ./eodata/gome2/offline/2a/2020/03/14
# ./eodata/gome2/offline/2a/2020/03/15
# ./eodata/gome2/offline/2a/2020/03/16
# ./eodata/gome2/offline/2a/2020/03/17
# ./eodata/gome2/offline/2a/2020/03/18
# ./eodata/gome2/offline/2a/2020/03/19
# ./eodata/gome2/offline/2a/2020/03/20
# ./eodata/gome2/offline/2a/2020/03/21
# ./eodata/gome2/offline/2a/2020/03/22
# ./eodata/gome2/offline/2a/2020/03/23
# ./eodata/gome2/offline/2a/2020/03/24
# ./eodata/gome2/offline/2a/2020/03/25
# ./eodata/gome2/offline/2a/2020/03/26
# ./eodata/gome2/offline/2a/2020/03/27
# ./eodata/gome2/offline/2a/2020/03/28
# ./eodata/gome2/offline/2a/2020/03/29
# ./eodata/gome2/offline/2a/2020/03/30
# ./eodata/gome2/offline/2a/2020/03/31

# %% [markdown]
# <br>

# %% [markdown]
# The three data arrays `data_array_a`, `cloud_fraction_a` and `index_scan_a` have the same number of ground pixels.

# %%
data_array_a, cloud_fraction_a, index_scan_a
# Out:
# (<xarray.DataArray 'NO2Tropo' (ground_pixel: 211163)>
#  array([-1., -1., -1., ..., -1., -1., -1.], dtype=float32)
#  Coordinates:
#      latitude   (ground_pixel) float32 78.54998 78.497986 ... -84.389786
#      longitude  (ground_pixel) float32 198.78352 196.99515 ... 41.96278 38.35278
#  Dimensions without coordinates: ground_pixel
#  Attributes:
#      long_name:  Tropospheric column density of NO2
#      units:      mol/cm²,
#  <xarray.DataArray 'cloud_fraction' (ground_pixel: 211163)>
#  array([0.9896364 , 0.8773051 , 0.9714895 , ..., 0.7652889 , 0.7581082 ,
#         0.75459504], dtype=float32)
#  Coordinates:
#      latitude   (ground_pixel) float32 78.54998 78.497986 ... -84.389786
#      longitude  (ground_pixel) float32 198.78352 196.99515 ... 41.96278 38.35278
#  Dimensions without coordinates: ground_pixel
#  Attributes:
#      long_name:  Cloud Fraction
#      units:      -,
#  <xarray.DataArray 'indexflag' (ground_pixel: 211163)>
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int32)
#  Coordinates:
#      latitude   (ground_pixel) float32 78.54998 78.497986 ... -84.389786
#      longitude  (ground_pixel) float32 198.78352 196.99515 ... 41.96278 38.35278
#  Dimensions without coordinates: ground_pixel
#  Attributes:
#      long_name:  Index in Scan
#      units:      -)

# %% [markdown]
# <br>

# %% [markdown]
# ### Load total column NO2, cloud fraction and index scan values for March 2020 from Metop-B

# %% [markdown]
# Now we can repeat the steps above for the data files for March 2020 from Metop-B.

# %% [markdown]
# #### Load NO2, cloud fraction and index scan values for one day in March 2020 from the Metop-B satellite

# %%
directory_2b= './eodata/gome2/offline/2b/2020/03/'
folder_list = glob.glob(directory_2b+'*')

data_array_b = load_l2_data_xr(folder_list[0], 
                               'TOTAL_COLUMNS', 
                               'NO2Tropo', 
                               'GEOLOCATION/LatitudeCentre', 
                               'GEOLOCATION/LongitudeCentre', 
                               1, 
                               paramname='NO2Tropo', 
                               unit='mol/cm\u00b2',
                               longname='Tropospheric column density of NO2')

cloud_fraction_b = load_l2_data_xr(folder_list[0], 
                                   'CLOUD_PROPERTIES', 
                                   'CloudFraction', 
                                   'GEOLOCATION/LatitudeCentre', 
                                   'GEOLOCATION/LongitudeCentre', 
                                   1, 
                                   paramname='cloud_fraction', 
                                   unit='-', 
                                   longname='Cloud Fraction')

index_scan_b = load_l2_data_xr(folder_list[0], 
                               'GEOLOCATION', 
                               'IndexInScan', 
                               'GEOLOCATION/LatitudeCentre', 
                               'GEOLOCATION/LongitudeCentre', 
                               1, paramname='indexflag', 
                               unit='-', 
                               longname='Index in Scan')

# %% [markdown]
# <br>

# %% [markdown]
# #### Loop through all days of March 2020 and load NO2, cloud fraction and index scan values from Metop-B into one DataArray object

# %%
for folder in folder_list[1:]:
    print(folder)
    data_array = load_l2_data_xr(folder,
                                 'TOTAL_COLUMNS', 
                                 'NO2Tropo', 
                                 'GEOLOCATION/LatitudeCentre', 
                                 'GEOLOCATION/LongitudeCentre', 
                                 1, 
                                 paramname='NO2Tropo', 
                                 unit='mol/cm\u00b2',
                                 longname='Tropospheric column density of NO2')
    
    data_array_b = xr.concat([data_array_b, data_array], dim='ground_pixel')
    
    cloud_fraction = load_l2_data_xr(folder, 
                                     'CLOUD_PROPERTIES', 
                                     'CloudFraction', 
                                     'GEOLOCATION/LatitudeCentre', 
                                     'GEOLOCATION/LongitudeCentre', 
                                     1, 
                                     paramname='cloud_fraction', 
                                     unit='-', 
                                     longname='Cloud Fraction')
    
    cloud_fraction_b = xr.concat([cloud_fraction_b, cloud_fraction], dim='ground_pixel')

    index_scan = load_l2_data_xr(folder, 
                                 'GEOLOCATION', 
                                 'IndexInScan',
                                 'GEOLOCATION/LatitudeCentre', 
                                 'GEOLOCATION/LongitudeCentre', 
                                 1, 
                                 paramname='indexflag', 
                                 unit='-', 
                                 longname='Index in Scan')
    
    index_scan_b = xr.concat([index_scan_b, index_scan], dim='ground_pixel')
# Out:
# ./eodata/gome2/offline/2b/2020/03/02
# ./eodata/gome2/offline/2b/2020/03/03
# ./eodata/gome2/offline/2b/2020/03/04
# ./eodata/gome2/offline/2b/2020/03/05
# ./eodata/gome2/offline/2b/2020/03/06
# ./eodata/gome2/offline/2b/2020/03/07
# ./eodata/gome2/offline/2b/2020/03/08
# ./eodata/gome2/offline/2b/2020/03/09
# ./eodata/gome2/offline/2b/2020/03/10
# ./eodata/gome2/offline/2b/2020/03/11
# ./eodata/gome2/offline/2b/2020/03/12
# ./eodata/gome2/offline/2b/2020/03/13
# ./eodata/gome2/offline/2b/2020/03/14
# ./eodata/gome2/offline/2b/2020/03/15
# ./eodata/gome2/offline/2b/2020/03/16
# ./eodata/gome2/offline/2b/2020/03/17
# ./eodata/gome2/offline/2b/2020/03/18
# ./eodata/gome2/offline/2b/2020/03/19
# ./eodata/gome2/offline/2b/2020/03/20
# ./eodata/gome2/offline/2b/2020/03/21
# ./eodata/gome2/offline/2b/2020/03/22
# ./eodata/gome2/offline/2b/2020/03/23
# ./eodata/gome2/offline/2b/2020/03/24
# ./eodata/gome2/offline/2b/2020/03/25
# ./eodata/gome2/offline/2b/2020/03/26
# ./eodata/gome2/offline/2b/2020/03/27
# ./eodata/gome2/offline/2b/2020/03/28
# ./eodata/gome2/offline/2b/2020/03/29
# ./eodata/gome2/offline/2b/2020/03/30
# ./eodata/gome2/offline/2b/2020/03/31

# %% [markdown]
# <br>

# %% [markdown]
# ### Concatenate the data arrays from the two satellites Metop-A and Metop-B

# %% [markdown]
# You can concatenate two data arrays with xarray's function `xr.concat()`. We want to use `ground_pixel` as the dimension data values get concatenated. We concatenate the data arrays for three variables, `NO2 data array`, `cloud fraction` and `index scan`.

# %%
data_ab = xr.concat([data_array_a, data_array_b], dim='ground_pixel')

cloud_fraction_ab = xr.concat([cloud_fraction_a, cloud_fraction_b], dim='ground_pixel')

index_scan_ab = xr.concat([index_scan_a, index_scan_b], dim='ground_pixel')

# %% [markdown]
# <br>

# %% [markdown]
# The three data arrays have the same amount of ground pixels (15410072).

# %%
data_ab, cloud_fraction_ab, index_scan_ab
# Out:
# (<xarray.DataArray 'NO2Tropo' (ground_pixel: 12619560)>
#  array([-1., -1., -1., ..., -1., -1., -1.], dtype=float32)
#  Coordinates:
#      latitude   (ground_pixel) float32 78.54998 78.497986 ... -77.769325
#      longitude  (ground_pixel) float32 198.78352 196.99515 ... 119.39467
#  Dimensions without coordinates: ground_pixel
#  Attributes:
#      long_name:  Tropospheric column density of NO2
#      units:      mol/cm²,
#  <xarray.DataArray 'cloud_fraction' (ground_pixel: 12619560)>
#  array([0.9896364 , 0.8773051 , 0.9714895 , ..., 0.78648883, 0.8038568 ,
#         0.8323481 ], dtype=float32)
#  Coordinates:
#      latitude   (ground_pixel) float32 78.54998 78.497986 ... -77.769325
#      longitude  (ground_pixel) float32 198.78352 196.99515 ... 119.39467
#  Dimensions without coordinates: ground_pixel
#  Attributes:
#      long_name:  Cloud Fraction
#      units:      -,
#  <xarray.DataArray 'indexflag' (ground_pixel: 12619560)>
#  array([0, 0, 0, ..., 0, 0, 0], dtype=int32)
#  Coordinates:
#      latitude   (ground_pixel) float32 78.54998 78.497986 ... -77.769325
#      longitude  (ground_pixel) float32 198.78352 196.99515 ... 119.39467
#  Dimensions without coordinates: ground_pixel
#  Attributes:
#      long_name:  Index in Scan
#      units:      -)

# %% [markdown]
# <br>

# %% [markdown]
# ## <a id='mask'></a>Mask and flag low-quality pixels

# %% [markdown]
# Low quality measurements are flagged out in three ways:
# - negative values
# - pixels with a cloud fraction higher than 20%, and
# - backward scan pixels

# %% [markdown]
# #### Flag negative values from the NO2 data array

# %% [markdown]
# Negative values can be flagged out with xarray's function `xr.where`. We cast only positive values and if value is negative, it is replaced with `NaN`.

# %%
data_ab_flagged = xr.where(data_ab > 0, data_ab, np.nan)
data_ab_flagged
# Out:
# <xarray.DataArray 'NO2Tropo' (ground_pixel: 12619560)>
# array([nan, nan, nan, ..., nan, nan, nan], dtype=float32)
# Coordinates:
#     latitude   (ground_pixel) float32 78.54998 78.497986 ... -77.769325
#     longitude  (ground_pixel) float32 198.78352 196.99515 ... 119.39467
# Dimensions without coordinates: ground_pixel

# %% [markdown]
# <br>

# %% [markdown]
# #### Mask backward scan pixels

# %% [markdown]
# The `IndexInScan` information is an integer value from 0 to 3, with the following descrition:
# - 0-2 forward scan (0-east part of scan, 1-centre part of scan, 2-west part of scan)
# - 3 backward scan
# Thus, we want to mask out all pixels which have a index scan flag of three and want to keep the pixels with index scan flag 0, 1 and 2.
#
# You can find more information on all the metadata of the GOME-2 Level 2 Trace Gas data in the [Product User Manual](https://acsaf.org/docs/pum/Product_User_Manual_NTO_OTO_DR_GDP48_Jun_2017.pdf).
#
# For masking, we can use the function [generate_masked_array](./functions.ipynb#generate_masked_array). We set the drop keyword argument to `False` to ensure the same amount of ground pixels during the masking process.

# %%
no2_ab_masked_is = generate_masked_array(data_ab_flagged, index_scan_ab, 3 , '!=', drop=False)
no2_ab_masked_is
# Out:
# <xarray.DataArray (ground_pixel: 12619560)>
# array([nan, nan, nan, ..., nan, nan, nan], dtype=float32)
# Coordinates:
#     latitude   (ground_pixel) float32 78.54998 78.497986 ... -77.769325
#     longitude  (ground_pixel) float32 198.78352 196.99515 ... 119.39467
# Dimensions without coordinates: ground_pixel

# %% [markdown]
# <br>

# %% [markdown]
# #### Mask cloud fraction information

# %% [markdown]
# We only want to keep pixels with a cloud fraction less than 20%. To mask it, we can use again the [generate_masked_array](./functions.ipynb#generate_masked_array) function and set the masking conditions to `less than` 0.2. We now set the drop keywork argument to `True`, as this is our last masking step and there is no benefit in keeping the non-valid pixels.

# %%
no2_ab_masked_is_cf = generate_masked_array(no2_ab_masked_is, cloud_fraction_ab, 0.2 , '<', drop=True)
no2_ab_masked_is_cf
# Out:
# <xarray.DataArray (ground_pixel: 945400)>
# array([3.4500600e+15, 7.9134595e+15, 2.2353812e+15, ..., 9.4519755e+14,
#        3.1140291e+14, 1.8073882e+14], dtype=float32)
# Coordinates:
#     latitude   (ground_pixel) float32 40.415627 40.505295 ... -63.425625
#     longitude  (ground_pixel) float32 123.88063 123.42716 ... 116.09011
# Dimensions without coordinates: ground_pixel

# %% [markdown]
# <br>

# %% [markdown]
# ## <a id='binning'></a>Binning of L2 data onto a defined two-dimensional grid

# %% [markdown]
# The longitude values of the AC SAF GOME-2 Level 2 data are stored as 0 to 360 degrees longitudes. In order to visualize the data on a -180 to 180 degrees grid, we have to convert the longitude values first. We can use the `assign_coords` function of the xarray library to re-assign the longitude values.

# %%
no2_ab_masked = no2_ab_masked_is_cf.assign_coords(longitude=(((no2_ab_masked_is_cf.longitude + 180) % 360) - 180))
no2_ab_masked
# Out:
# <xarray.DataArray (ground_pixel: 945400)>
# array([3.4500600e+15, 7.9134595e+15, 2.2353812e+15, ..., 9.4519755e+14,
#        3.1140291e+14, 1.8073882e+14], dtype=float32)
# Coordinates:
#     latitude   (ground_pixel) float32 40.415627 40.505295 ... -63.425625
#     longitude  (ground_pixel) float32 123.880615 123.427155 ... 116.09012
# Dimensions without coordinates: ground_pixel

# %% [markdown]
# <br>

# %% [markdown]
# ### Retrieve data values and latitude and longitude data information

# %% [markdown]
# For the binning process, we need the latitude and longitude information. We can retrieve the data from our masked data object.

# %%
y = no2_ab_masked.latitude.data
x = no2_ab_masked.longitude.data

len(x), len(y)
# Out:
# (945400, 945400)

# %% [markdown]
# And we also want to retrieve the NO2 data values and call the new variable `z`.

# %%
z = no2_ab_masked.data
len(z)
# Out:
# 945400

# %% [markdown]
# <br>

# %% [markdown]
# ### Bin the data onto a 2D-grid with `np.histogram2d`

# %% [markdown]
# With `np.histogram2d`, we can bin the data onto a pre-defined 2-dimensional grid (called bins). By assigning our data value object `z` to the keyword argument `weights`, the bin gets assigned the data value of the point that falls into the cell.
#
# Since there will be more data points assigned to one cell (bin), we also create a `counts` array, which sums up the number of data points fallen into a bin.
#
# The example below builds a regular grid of 1 deg x 1 deg. NO2 climate records can be binned onto a grid up to 0.25 deg x 0.25 deg. If you wish to make the grid with a finer resolution, you can set the bins to `bins=(720,1440)`.

# %%
zi, yi, xi = np.histogram2d(y, x, bins=(180,360), weights=z, normed=False)
counts, _, _ = np.histogram2d(y, x, bins=(180,360))

# %% [markdown]
# <br>

# %% [markdown]
# ### Build the `arithmetic mean` of all the data points fallen into a bin

# %% [markdown]
# The `counts` array can be used to build the`arithmetic mean` of all the data points fallen into one bin.

# %%
zi = zi / counts
zi
# Out:
# array([[2.00722814e+14, 1.17744180e+15, 6.29051044e+14, ...,
#         5.49384857e+14, 1.00823181e+15,            nan],
#        [5.93709838e+14, 3.44888298e+14, 3.13064528e+13, ...,
#                    nan,            nan,            nan],
#        [4.69670477e+14, 4.90900245e+14, 9.04079755e+14, ...,
#         1.17186465e+15, 2.52310307e+14,            nan],
#        ...,
#        [           nan,            nan,            nan, ...,
#                    nan,            nan,            nan],
#        [           nan,            nan,            nan, ...,
#                    nan,            nan,            nan],
#        [           nan,            nan,            nan, ...,
#                    nan,            nan,            nan]])

# %% [markdown]
# <br>

# %% [markdown]
# ## <a id='visualize'></a>Visualize the gridded Level 3 NO2 climate record for March 2020

# %% [markdown]
# The final step is to visualize the gridded data array, together with the latitude and longitude information. We can use the function [visualize_pcolormesh](./functions.ipynb#visualize_pcolormesh) to plot the data with matplotlib's plotting function `pcolormesh`.
#
# We multiple the NO2 values with `1e-15` to facilitate the plotting.

# %%
    'lonmin':-10.0,
            'lonmax':30.0,
            'latmin':35.0,
            'latmax':60.0

# %%
visualize_pcolormesh(zi*1e-15, 
                     xi, 
                     yi, 
                     ccrs.PlateCarree(), 
                     'afmhot_r', 
                     '*1e-15 mol/cm\u00b2', 
                     'Gridded level 3 data of tropospheric column density of NO2 for March 2020', 
                      0, 12, 
                      -10, 30, 35, 60, 
                      log=False, 
                      set_global=False)
# Out:
# (<Figure size 1440x720 with 2 Axes>,
#  <GeoAxesSubplot:title={'center':'Gridded level 3 data of tropospheric column density of NO2 for March 2020'}>)

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# <a href="./00_index.ipynb"><< Index </a><br>
# <a href="./01_introduction_to_python_and_jupyter.ipynb"><< 01 - Introduction to Python and Jupyter </a><span style="float:right;"><a href="./03_case_study_covid-19_GOME2_anomaly_map.ipynb">03 - Covid-19 case study - GOME-2 anomaly map >></a></span>

# %% [markdown]
# <hr>

# %% [markdown]
# <img src='./img/copernicus_logo.png' alt='Logo EU Copernicus' align='right' width='20%'><br><br><br><br>
#
# <p style="text-align:right;">This project is licensed under the <a href="./LICENSE">MIT License</a> and is developed under a Copernicus contract.
